# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhisharma57350-ops/python/blob/main/Function_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def numbers(n):
   for i in range(n):
     print(i)
numbers(3)
numbers(5)
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 3
# 4

# %%
def fact_sum(n):
 sum=0
 fact=1
 for i in range(1,n+1):
  fact=fact*i
  sum=sum+fact
  print(sum)
fact_sum(4)
fact_sum(5)
# Out:
# 1
# 3
# 9
# 33
# 1
# 3
# 9
# 33
# 153

# %%
def num(n):
  if n%2==0:
    print("the number is even")
  else:
    print("the number is odd")
num(20)
num(61)
# Out:
# the number is even
# the number is odd

# %%
def fact_sum(even):
  sum=0
  fact=1
  n=8
  for i in range(2,n+1):
     fact=fact*i
     if i%2==0:
      sum=sum+fact
      print(sum)
fact_sum(8)
# Out:
# 2
# 26
# 746
# 41066

# %%
def descending(n):
 while n>0:
  print(n)
  n=n-1
descending(3)
descending(6)
# Out:
# 3
# 2
# 1
# 6
# 5
# 4
# 3
# 2
# 1

# %%
def ascending(n):
   while n<10:
    print(n)
    n=n+1
ascending(4)
# Out:
# 4
# 5
# 6
# 7
# 8
# 9

# %%
def pal(temp):
  n=temp
  temp=n
  rev=0
  while n>0:
     digit=n%10
     n=int(n/10)
     rev=rev*10+digit
  if temp==rev:
    print("pen")
  else:
    print("not a pen")
pal(121)
pal(456)
pal(678)
pal(1001)
# Out:
# pen
# not a pen
# not a pen
# pen

# %%
n=3456
temp=n
rev=0
while n>0:
  digit=n%10
  n=int(n/10)
  rev=rev*10+digit
if temp==rev:
  print("pallondrom")
else:
  print("not a pallondrom")
# Out:
# not a pallondrom

# %%
print(bool(0),bool(1))
# Out:
# False True

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
None==False
# Out:
# False

# %%
print("python"[::-1])
# Out:
# nohtyp

# %%
name="nidhi"
print(name[::-1])
# Out:
# ihdin

# %%
len(" ")
# Out:
# 1

# %%
print("hello"+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1684405547.py in <cell line: 0>()
# ----> 1 print("hello"+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("a"*3)
# Out:
# aaa

# %%
a="  my name is nidhi sharma  "
print(a.strip())
# Out:
# my name is nidhi sharma

# %%
print("python".capitalize())
# Out:
# Python

# %%
a="my name is nidhi sharma"
print(a.title())
# Out:
# My Name Is Nidhi Sharma

# %%
a="nidhi"
print(a.upper())
# Out:
# NIDHI

# %%
a="my name is nidhi sharma"
print(a.capitalize())
# Out:
# My name is nidhi sharma

# %%
print("hello".find("l"))
# Out:
# 2

# %%
print("ABc"=="ABc")
# Out:
# True

# %%
a=[1,2,3]
a.append([4,5])
print(a)
# Out:
# [1, 2, 3, [4, 5]]

# %%
a=[1,2,3,4]
print(a.pop(3))
# Out:
# 4

# %%
a=[1,2,3]
b=a
b.append(4)
print(a)
b.remove(1)
print(a)
# Out:
# [1, 2, 3, 4]
# [2, 3, 4]

# %%
a=[]

# %%
print([1,2,3]*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
print(2**3**2)
# Out:
# 512

# %%
print(type(type(5)))
# Out:
# <class 'type'>

# %%
a=10
b=a
a=20
print(b)
# Out:
# 10

# %%
print(bool(0),bool("0"))
# Out:
# False True

# %%
print(bool(1),bool("1"))
# Out:
# True True

# %%
print(id(10)==id(10))
# Out:
# True

# %%
print(3*"hi")
# Out:
# hihihi

# %%
print(float("95"))
# Out:
# 95.0

# %%
print(type(()))
# Out:
# <class 'tuple'>

# %%
print(type((5)))
# Out:
# <class 'int'>

# %%
print(type((5,)))
# Out:
# <class 'tuple'>

# %%
a=b=c=5
a+=1
print(c)
# Out:
# 5

# %%
x=5
y=x=x+2
print(y)
# Out:
# 7

# %%
a,b=5,10
a,b=b,a
print(a,b)
# Out:
# 10 5

# %%
a=5
a=a+2*3
print(a)
# Out:
# 11

# %%
x=5
x*=2+3
print(x)
# Out:
# 25
