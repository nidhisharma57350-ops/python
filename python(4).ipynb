# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhisharma57350-ops/python/blob/main/python(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=5
while n>0:
   print(n)
   n=n-1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
n=1
while n<4:
   print(n)
   n=n+1
# Out:
# 1
# 2
# 3

# %%
n=11
while n>0:
  print(n)
  n=n-4
# Out:
# 11
# 7
# 3

# %%
n=10
while n>0:
   print(n)
   n=n-4
# Out:
# 10
# 6
# 2

# %%
sum=0
n=0
while n<10:
  n=n+1
  sum=sum+n
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
sum=0
n=0
while n<15:
  n=n+1
  sum=sum+n
print(sum)
# Out:
# 120

# %%
n=7
fact=1
while n>0:
  fact=fact*n
  n=n-1
print(fact)
# Out:
# 5040

# %%
n=34567
while n>0:
  digit=n%10
  n=int(n/10)
  print(digit)
# Out:
# 7
# 6
# 5
# 4
# 3

# %%
n=5678
while n>0:
   digit=n%10
   n=int(n/10)
   print(digit)
# Out:
# 8
# 7
# 6
# 5

# %%
n=5678
rev=0
while n>0:
   digit=n%10
   n=int(n/10)
   rev=rev*10+digit
   print(rev)
# Out:
# 8
# 87
# 876
# 8765

# %%
n=1256
temp=n
rev=0
while n>0:
   digit=n%10
   n=n//10
   rev=rev*10+digit
if temp==rev:
    print("pallondrom")
else:
    print("not a pallondrom")
# Out:
# pallondrom

# %%
num=5678
num2=str(num)
rev=num2[::-1]
result=int(rev)/5
print(result)
# Out:
# 1753.0

# %%
n=65
n2=str(n)
rev=n2[::-1]
result=int(rev)%5
print(result)
# Out:
# 1

# %%
n=37899
rev=0
while n>0:
    digit=n%10
    n=int(n/10)
    rev=rev*10+digit
print(rev)
# Out:
# 99873

# %%
n=76324
sum=0
while n>0:
   digit=n%10
   n=int(n/10)
   sum=sum+digit
print(sum)
# Out:
# 22

# %%
sum=0
for i in range(1,11):
  square=i*i
  sum=sum+square
print(sum)
# Out:
# 385

# %%
n=5
square=n*n
print(square)
# Out:
# 25

# %%
n=5
cube=n*n*n
print(cube)
# Out:
# 125

# %%
sum=0
for i in range(1,11):
  if i%2==0:
    sum=sum+i*i
print(sum)
# Out:
# 220

# %%
sum=0
for i in range(1,11):
  if i%2!=0:
    sum=sum+i*i
print(sum)
# Out:
# 165

# %%
sum=0
for i in range(1,11):
  sum=sum+i**5
print(sum)
# Out:
# 220825

# %%
sum1=0
sum2=0
for i in range(1,11):
  if i%2!=0:
    sum1=sum1+i*i
  if i%2==0:
    sum2=sum2+i**3
total=sum1+sum2
print(total)
# Out:
# 1965

# %%
sum=0
a=[16,81,256,625]
for i in a:
  sum=sum+i**0.25
print(sum)
# Out:
# 14.0

# %%
#list comprehension:
a=[i for i in range(5)]
print(a)
# Out:
# [0, 1, 2, 3, 4]

# %%
a=[i*i for i in range(5)]
print(a)
# Out:
# [0, 1, 4, 9, 16]

# %%
a=[i for i in range(5) if i%2==0]
print(a)
# Out:
# [0, 2, 4]

# %%
a=(i for i in range(5))
print(a)
# Out:
# <generator object <genexpr> at 0x7b176aa0bac0>
