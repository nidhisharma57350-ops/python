# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhisharma57350-ops/python/blob/main/python(8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.array([5,6,7])
print(x)
# Out:
# [5 6 7]

# %%
x=[5,6,7],[6,8,4]
y=[5,2,3]
x[0]
print(x[0])
x[0][1]
print(x[0][1])
x=np.array([5,6,7]),([6,8,4])
y=np.array([5,2,3])
z=x+y
print(z)
x=np.array([5,6,7]),([6,8,4])
y=np.array([5])
p=x+y
print(p)
# Out:
# [5, 6, 7]
# 6
# [[10  8 10]
#  [11 10  7]]
# [[10 11 12]
#  [11 13  9]]

# %%
import pandas as pd
employees={"names":["nidhi","sunidhi","priya"],
"ages":[22,23,24],
"salaries":[100000,90000,95000]}
df=pd.DataFrame(employees)
print(df)
# Out:
#      names  ages  salaries
# 0    nidhi    22    100000
# 1  sunidhi    23     90000
# 2    priya    24     95000

# %%
import numpy as np
x=np.array([4,6,8]),([2,4,6])
y=np.array([5])
z=x+y
print(z)
# Out:
# [[ 9 11 13]
#  [ 7  9 11]]

# %%
import csv
with open("sales_data.csv","r")as file:
   reader=csv.reader(file)
   for row in reader:
     print(row)
import pandas as pd
df=pd.read_csv("sales_data.csv")
df.groupby("State")["Amount"].sum().plot(kind="bar")
state_wise_sale=df.groupby("State")["Amount"].sum()
print(state_wise_sale)
state_wise_sale.to_csv("state_wise_sale.csv")
# Out:
# ['Customer_ID', 'Customer_Name', 'Gender', 'State', 'Product', 'Amount', 'Date']
# ['1', 'Antonio', 'Male', 'Karnataka', 'Shirt', '6591', '6/12/2025']
# ['2', 'Dustin', 'Female', 'Punjab', 'Tablet', '14122', '10/6/2024']
# ['3', 'Donald', 'Female', 'Maharashtra', 'Rings', '15149', '7/28/2025']
# ['4', 'Victor', 'Female', 'Kerala', 'Watch', '30921', '1/22/2025']
# ['5', 'Elizabeth', 'Female', 'Maharashtra', 'Shirt', '48459', '6/15/2025']
# ['6', 'Tammy', 'Male', 'Punjab', 'Shoes', '30097', '4/18/2025']
# ['7', 'Gabriel', 'Male', 'Maharashtra', 'Rings', '37692', '9/30/2025']
# ['8', 'Crystal', 'Female', 'Tamil Nadu', 'Watch', '10292', '2/2/2025']
# ['9', 'Jill', 'Male', 'UP', 'Phone', '19755', '2/18/2025']
# ['10', 'Alexandra', 'Female', 'Karnataka', 'Shoes', '18121', '9/17/2025']
# ['11', 'Erin', 'Female', 'Punjab', 'Camera', '916', '8/8/2025']
# ['12', 'Jared', 'Male', 'Punjab', 'Camera', '20080', '8/18/2025']
# ['13', 'George', 'Female', 'Tamil Nadu', 'Rings', '32687', '7/25/2025']
# ...

# %%
import csv
with open("sales_data.csv","r")as file:
   reader=csv.reader(file)
   for row in reader:
     print(row)
import pandas as pd
df=pd.read_csv("sales_data.csv")
df.groupby("State")["Amount"].sum().plot(kind="bar")
state_wise_sale=df.groupby("State")["Amount"].sum()
print(state_wise_sale)
state_wise_sale.to_csv("state_wise_sale.csv")
# Out:
# ['Customer_ID', 'Customer_Name', 'Gender', 'State', 'Product', 'Amount', 'Date']
# ['1', 'Antonio', 'Male', 'Karnataka', 'Shirt', '6591', '6/12/2025']
# ['2', 'Dustin', 'Female', 'Punjab', 'Tablet', '14122', '10/6/2024']
# ['3', 'Donald', 'Female', 'Maharashtra', 'Rings', '15149', '7/28/2025']
# ['4', 'Victor', 'Female', 'Kerala', 'Watch', '30921', '1/22/2025']
# ['5', 'Elizabeth', 'Female', 'Maharashtra', 'Shirt', '48459', '6/15/2025']
# ['6', 'Tammy', 'Male', 'Punjab', 'Shoes', '30097', '4/18/2025']
# ['7', 'Gabriel', 'Male', 'Maharashtra', 'Rings', '37692', '9/30/2025']
# ['8', 'Crystal', 'Female', 'Tamil Nadu', 'Watch', '10292', '2/2/2025']
# ['9', 'Jill', 'Male', 'UP', 'Phone', '19755', '2/18/2025']
# ['10', 'Alexandra', 'Female', 'Karnataka', 'Shoes', '18121', '9/17/2025']
# ['11', 'Erin', 'Female', 'Punjab', 'Camera', '916', '8/8/2025']
# ['12', 'Jared', 'Male', 'Punjab', 'Camera', '20080', '8/18/2025']
# ['13', 'George', 'Female', 'Tamil Nadu', 'Rings', '32687', '7/25/2025']
# ...

# %%
import csv
with open("sales.csv","r")as file:
    reader=csv.reader(file)
    for row in reader:
      print(row)
import pandas as pd
df=pd.read_csv("sales.csv")
df["final_price"] = df["Amount"]*df["quantity"]*(1 - df["discount"]/100)
print(df)
df.to_csv("final_price.csv")
# Out:
# ['Customer', 'Gender', 'State', 'quantity', 'Product', 'Amount', 'discount']
# ['Alice', 'F', 'California', '2', 'Laptop', '1200', '5']
# ['Bob', 'M', 'Texas', '3', 'Phone', '800', '10']
# ['Charlie', 'M', 'California', '4', 'Tablet', '450', '15']
# ['Diana', 'F', 'New York', '5', 'Laptop', '1300', '10']
# ['Ethan', 'M', 'Texas', '3', 'Headphones', '200', '10']
# ['Fiona', 'F', 'Florida', '2', 'Phone', '850', '5']
# ['George', 'M', 'California', '5', 'Phone', '750', '5']
# ['Hannah', 'F', 'Texas', '4', 'Tablet', '500', '10']
# ['Ian', 'M', 'Florida', '7', 'Laptop', '1400', '15']
# ['Jane', 'F', 'New York', '2', 'Headphones', '220', '10']
# ['Kevin', 'M', 'New York', '3', 'Laptop', '976', '10']
# ['Laura', 'F', 'California', '4', 'Tablet', '1186', '5']
# ['Mike', 'M', 'Florida', '5', 'Headphones', '315', '5']
# ['Nina', 'F', 'California', '3', 'Laptop', '1445', '10']
# ['Oscar', 'F', 'California', '2', 'Tablet', '560', '15']
# ['Paula', 'M', 'Texas', '5', 'Headphones', '1998', '10']
# ...

# %%
import pandas as pd
employee={"names":["nidhi","neha",None,"shikha","radha"],
"ages":[22,23,24,None,26],
"salary":[30000,40000,None,50000,60000]}
df=pd.DataFrame(employee)
df.info()
df.columns
df.dtypes
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   4 non-null      object
#  1   ages    4 non-null      float64
#  2   salary  4 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 252.0+ bytes
#     names  ages   salary
# 0   nidhi  22.0  30000.0
# 1    neha  23.0  40000.0
# 2    None  24.0      NaN
# 3  shikha   NaN  50000.0
# 4   radha  26.0  60000.0

# %%
import pandas as pd
employee={"names":["nidhi","sunidhi",None,"neha","sneha"],
"ages":[22,23,24,None,25],
"salary":[50000,60000,None,60000,65000]}
df.fillna({"names":"unknown","salary":df["salary"].mean(),"ages":df["ages"].mean()})
# Out:
#      names   ages   salary
# 0    nidhi  22.00  30000.0
# 1     neha  23.00  40000.0
# 2  unknown  24.00  45000.0
# 3   shikha  23.75  50000.0
# 4    radha  26.00  60000.0

# %%
.vstack()
kaggle
start_kernel
